# %%
ph_nm=[]
ph_pr=[]

import requests
from bs4 import BeautifulSoup
page_num=input("Enter page number: ")
for i in range(1,int(page_num)+1):
    url="https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off="+str(i)
    response = requests.get(url)

    soup= BeautifulSoup(response.content,"html.parser")
    title=soup.find_all("div",{"class":"_4rR01T"})
    price=soup.find_all("div",{"class":"_30jeq3 _1_WHN1"})
    print("phone in page: "+str(i))
    print(len(title))
    for i in title:
        ph_nm.append(i.text)
    for i in price:
        ph_pr.append(i.text)
# Out:
# Enter page number: 5
# phone in page: 1
# 24
# phone in page: 2
# 24
# phone in page: 3
# 24
# phone in page: 4
# 24
# phone in page: 5
# 24

# %%
for i in ph_nm:
    print(i)
# Out:
# APPLE iPhone 14 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 128 GB)
# APPLE iPhone 14 (Midnight, 128 GB)
# APPLE iPhone 12 (White, 64 GB)
# APPLE iPhone 14 Plus (Starlight, 128 GB)
# APPLE iPhone 14 Plus (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 128 GB)
# APPLE iPhone 12 (Black, 64 GB)
# APPLE iPhone 12 (Blue, 64 GB)
# APPLE iPhone 14 Plus (Purple, 128 GB)
# APPLE iPhone 14 Plus (Midnight, 128 GB)
# APPLE iPhone 12 (Black, 128 GB)
# APPLE iPhone 12 (White, 128 GB)
# APPLE iPhone 12 (Green, 64 GB)
# APPLE iPhone 12 (Blue, 128 GB)
# APPLE iPhone 15 (Black, 128 GB)
# APPLE iPhone 15 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 256 GB)
# APPLE iPhone 14 (Blue, 256 GB)
# APPLE iPhone 15 (Green, 128 GB)
# APPLE iPhone 15 (Pink, 128 GB)
# APPLE iPhone 13 (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 128 GB)
# APPLE iPhone 14 (Midnight, 128 GB)
# APPLE iPhone 12 (White, 64 GB)
# APPLE iPhone 14 Plus (Starlight, 128 GB)
# APPLE iPhone 14 Plus (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 128 GB)
# APPLE iPhone 12 (Black, 64 GB)
# APPLE iPhone 12 (Blue, 64 GB)
# APPLE iPhone 14 Plus (Purple, 128 GB)
# APPLE iPhone 14 Plus (Midnight, 128 GB)
# APPLE iPhone 12 (Black, 128 GB)
# APPLE iPhone 12 (White, 128 GB)
# APPLE iPhone 12 (Green, 64 GB)
# APPLE iPhone 12 (Blue, 128 GB)
# APPLE iPhone 15 (Black, 128 GB)
# APPLE iPhone 15 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 256 GB)
# APPLE iPhone 14 (Blue, 256 GB)
# APPLE iPhone 15 (Green, 128 GB)
# APPLE iPhone 15 (Pink, 128 GB)
# APPLE iPhone 13 (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 128 GB)
# APPLE iPhone 14 (Midnight, 128 GB)
# APPLE iPhone 12 (White, 64 GB)
# APPLE iPhone 14 Plus (Starlight, 128 GB)
# APPLE iPhone 14 Plus (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 128 GB)
# APPLE iPhone 12 (Black, 64 GB)
# APPLE iPhone 12 (Blue, 64 GB)
# APPLE iPhone 14 Plus (Purple, 128 GB)
# APPLE iPhone 14 Plus (Midnight, 128 GB)
# APPLE iPhone 12 (Black, 128 GB)
# APPLE iPhone 12 (White, 128 GB)
# APPLE iPhone 12 (Green, 64 GB)
# APPLE iPhone 12 (Blue, 128 GB)
# APPLE iPhone 15 (Black, 128 GB)
# APPLE iPhone 15 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 256 GB)
# APPLE iPhone 14 (Blue, 256 GB)
# APPLE iPhone 15 (Green, 128 GB)
# APPLE iPhone 15 (Pink, 128 GB)
# APPLE iPhone 13 (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 128 GB)
# APPLE iPhone 14 (Midnight, 128 GB)
# APPLE iPhone 12 (White, 64 GB)
# APPLE iPhone 14 Plus (Starlight, 128 GB)
# APPLE iPhone 14 Plus (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 128 GB)
# APPLE iPhone 12 (Black, 64 GB)
# APPLE iPhone 12 (Blue, 64 GB)
# APPLE iPhone 14 Plus (Purple, 128 GB)
# APPLE iPhone 14 Plus (Midnight, 128 GB)
# APPLE iPhone 12 (Black, 128 GB)
# APPLE iPhone 12 (White, 128 GB)
# APPLE iPhone 12 (Green, 64 GB)
# APPLE iPhone 12 (Blue, 128 GB)
# APPLE iPhone 15 (Black, 128 GB)
# APPLE iPhone 15 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 256 GB)
# APPLE iPhone 14 (Blue, 256 GB)
# APPLE iPhone 15 (Green, 128 GB)
# APPLE iPhone 15 (Pink, 128 GB)
# APPLE iPhone 13 (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 128 GB)
# APPLE iPhone 14 (Midnight, 128 GB)
# APPLE iPhone 12 (White, 64 GB)
# APPLE iPhone 14 Plus (Starlight, 128 GB)
# APPLE iPhone 14 Plus (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 128 GB)
# APPLE iPhone 12 (Black, 64 GB)
# APPLE iPhone 12 (Blue, 64 GB)
# APPLE iPhone 14 Plus (Purple, 128 GB)
# APPLE iPhone 14 Plus (Midnight, 128 GB)
# APPLE iPhone 12 (Black, 128 GB)
# APPLE iPhone 12 (White, 128 GB)
# APPLE iPhone 12 (Green, 64 GB)
# APPLE iPhone 12 (Blue, 128 GB)
# APPLE iPhone 15 (Black, 128 GB)
# APPLE iPhone 15 (Blue, 128 GB)
# APPLE iPhone 14 (Starlight, 256 GB)
# APPLE iPhone 14 (Blue, 256 GB)
# APPLE iPhone 15 (Green, 128 GB)
# APPLE iPhone 15 (Pink, 128 GB)
# APPLE iPhone 13 (Blue, 128 GB)
# APPLE iPhone 14 (Purple, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)

# %%
for j in ph_pr:
    print(i)
# Out:
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)
# APPLE iPhone 14 (Midnight, 256 GB)

# %%
import pandas as pd
data ={"phone_name":ph_nm,"phone_price":ph_pr}
df =pd.DataFrame(data)
print(df)
# Out:
#                                    phone_name phone_price
# 0              APPLE iPhone 14 (Blue, 128 GB)     ₹60,999
# 1         APPLE iPhone 14 (Starlight, 128 GB)     ₹61,999
# 2          APPLE iPhone 14 (Midnight, 128 GB)     ₹61,999
# 3              APPLE iPhone 12 (White, 64 GB)     ₹41,999
# 4    APPLE iPhone 14 Plus (Starlight, 128 GB)     ₹68,999
# ..                                        ...         ...
# 115           APPLE iPhone 15 (Green, 128 GB)     ₹79,900
# 116            APPLE iPhone 15 (Pink, 128 GB)     ₹79,900
# 117            APPLE iPhone 13 (Blue, 128 GB)     ₹51,999
# 118          APPLE iPhone 14 (Purple, 256 GB)     ₹71,999
# 119        APPLE iPhone 14 (Midnight, 256 GB)     ₹71,999
#
# [120 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   phone_name   120 non-null    object
#  1   phone_price  120 non-null    object
# dtypes: object(2)
# memory usage: 2.0+ KB
